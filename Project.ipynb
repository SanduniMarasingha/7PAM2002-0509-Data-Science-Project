# %%
import pandas as pd

# Load the dataset
file_path = r"C:\Users\Ruwan Hasitha\OneDrive - University of Hertfordshire\Final project\UK-HPI-full-file-2024-03.csv"
df = pd.read_csv(file_path)

# Display basic information in the dataset
print(df.info())
print(df.head())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 140580 entries, 0 to 140579
# Data columns (total 54 columns):
#  #   Column                  Non-Null Count   Dtype
# ---  ------                  --------------   -----
#  0   Date                    140580 non-null  object
#  1   RegionName              140580 non-null  object
#  2   AreaCode                140580 non-null  object
#  3   AveragePrice            140580 non-null  float64
#  4   Index                   140580 non-null  float64
#  5   IndexSA                 4929 non-null    float64
#  6   1m%Change               140156 non-null  float64
#  7   12m%Change              135768 non-null  float64
#  8   AveragePriceSA          4929 non-null    float64
#  9   SalesVolume             136113 non-null  float64
#  10  DetachedPrice           134031 non-null  float64
#  11  DetachedIndex           134031 non-null  float64
#  12  Detached1m%Change       133641 non-null  float64
#  13  Detached12m%Change      129375 non-null  float64
#  14  SemiDetachedPrice       134031 non-null  float64
#  15  SemiDetachedIndex       134031 non-null  float64
#  16  SemiDetached1m%Change   133641 non-null  float64
#  17  SemiDetached12m%Change  129375 non-null  float64
#  18  TerracedPrice           134058 non-null  float64
#  19  TerracedIndex           134058 non-null  float64
#  20  Terraced1m%Change       133668 non-null  float64
#  21  Terraced12m%Change      129402 non-null  float64
#  22  FlatPrice               134382 non-null  float64
#  23  FlatIndex               134382 non-null  float64
#  24  Flat1m%Change           133991 non-null  float64
#  25  Flat12m%Change          129714 non-null  float64
#  26  CashPrice               57624 non-null   float64
#  27  CashIndex               57624 non-null   float64
#  28  Cash1m%Change           57234 non-null   float64
#  29  Cash12m%Change          52944 non-null   float64
#  30  CashSalesVolume         56837 non-null   float64
#  31  MortgagePrice           57624 non-null   float64
#  32  MortgageIndex           57624 non-null   float64
#  33  Mortgage1m%Change       57234 non-null   float64
#  34  Mortgage12m%Change      52944 non-null   float64
#  35  MortgageSalesVolume     56839 non-null   float64
#  36  FTBPrice                58020 non-null   float64
#  37  FTBIndex                58020 non-null   float64
#  38  FTB1m%Change            57630 non-null   float64
#  39  FTB12m%Change           53340 non-null   float64
#  40  FOOPrice                57624 non-null   float64
#  41  FOOIndex                57624 non-null   float64
#  42  FOO1m%Change            57234 non-null   float64
#  43  FOO12m%Change           52944 non-null   float64
#  44  NewPrice                133367 non-null  float64
#  45  NewIndex                133571 non-null  float64
#  46  New1m%Change            133180 non-null  float64
#  47  New12m%Change           128903 non-null  float64
#  48  NewSalesVolume          131597 non-null  float64
#  49  OldPrice                133594 non-null  float64
#  50  OldIndex                133594 non-null  float64
#  51  Old1m%Change            133203 non-null  float64
#  52  Old12m%Change           128926 non-null  float64
#  53  OldSalesVolume          133584 non-null  float64
# dtypes: float64(51), object(3)
# memory usage: 57.9+ MB
# None
#          Date     RegionName   AreaCode  AveragePrice      Index  IndexSA  \
# 0  01/01/2004  Aberdeenshire  S12000034   81693.66964  40.864214      NaN
# 1  01/02/2004  Aberdeenshire  S12000034   81678.76231  40.856757      NaN
# 2  01/03/2004  Aberdeenshire  S12000034   83525.09702  41.780317      NaN
# 3  01/04/2004  Aberdeenshire  S12000034   84333.67900  42.184780      NaN
# 4  01/05/2004  Aberdeenshire  S12000034   86379.95396  43.208353      NaN
#
#    1m%Change  12m%Change  AveragePriceSA  SalesVolume  ...     NewPrice  \
# 0        NaN         NaN             NaN        388.0  ...  88436.13953
# 1  -0.018248         NaN             NaN        326.0  ...  88606.44649
# 2   2.260483         NaN             NaN        453.0  ...  90296.91375
# 3   0.968071         NaN             NaN        571.0  ...  90319.87844
# 4   2.426403         NaN             NaN        502.0  ...  91989.17763
#
#     NewIndex  New1m%Change  New12m%Change  NewSalesVolume     OldPrice  \
# 0  40.267250           NaN            NaN           103.0  81043.95084
# 1  40.344795      0.192576            NaN           107.0  80965.29542
# 2  41.114508      1.907838            NaN           140.0  82903.23948
# 3  41.124964      0.025432            NaN           180.0  84003.99161
# 4  41.885039      1.848208            NaN           167.0  86222.73484
#
#     OldIndex  Old1m%Change  Old12m%Change  OldSalesVolume
# 0  40.883367           NaN            NaN           285.0
# 1  40.843688     -0.097053            NaN           219.0
# 2  41.821302      2.393549            NaN           313.0
# 3  42.376586      1.327755            NaN           391.0
# 4  43.495852      2.641235            NaN           335.0
#
# [5 rows x 54 columns]

# %%
# Handle missing values in dataset
df = df.dropna()  # or use df.fillna() to fill missing values

# Convert 'Date' column to datetime type
df['Date'] = pd.to_datetime(df['Date'])

# Extract year and month
df['Year'] = df['Date'].dt.year
df['Month'] = df['Date'].dt.month

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Summary statistics
print(df.describe())

# Line plot of average prices over time for different regions
plt.figure(figsize=(14, 7))
sns.lineplot(data=df, x='Date', y='AveragePrice', hue='RegionName')
plt.title('Average House Prices Over Time by Region')
plt.show()

# Boxplot of average prices by property type
plt.figure(figsize=(14, 7))
sns.boxplot(data=df, x='RegionName', y='AveragePrice')
plt.title('Distribution of House Prices by Region')
plt.xticks(rotation=90)
plt.show()
# Out:
#         AveragePrice        Index      IndexSA    1m%Change   12m%Change  \
# count    1862.000000  1862.000000  1862.000000  1862.000000  1862.000000
# mean   227547.060270   119.253019   118.200898     0.378183     4.640937
# std     89720.297677    18.401391    18.214374     1.363162     3.922547
# min    112007.912300    77.290881    77.240070    -8.300000    -4.700000
# 25%    159791.707500   104.862178   103.253397    -0.259293     1.834386
# 50%    207644.500000   118.784230   118.157159     0.402311     4.350095
# 75%    265934.750000   130.820801   129.375000     1.041707     6.988371
# max    542387.000000   162.000000   159.600000     8.400000    20.555012
#
#        AveragePriceSA    SalesVolume  DetachedPrice  DetachedIndex  \
# count     1862.000000    1862.000000   1.862000e+03    1862.000000
# mean    225809.438100   21564.191192   3.706507e+05     119.700168
# std      89757.488601   28885.745314   1.745639e+05      18.608346
# min     110711.944000    1003.000000   1.864454e+05      78.674844
# 25%     156916.295450    5807.000000   2.591071e+05     105.033114
# 50%     205236.954000    8065.500000   3.240280e+05     119.286247
# 75%     265267.000000   13179.750000   4.116115e+05     131.775000
# max     532852.000000  180954.000000   1.085762e+06     161.100000
#
#        Detached1m%Change  ...  New1m%Change  New12m%Change  NewSalesVolume  \
# count        1862.000000  ...   1862.000000    1862.000000     1862.000000
# mean            0.391189  ...      0.510563       5.299806     2226.922664
# std             1.369190  ...      2.262861       3.922622     3224.145606
# min           -12.996736  ...     -6.812824      -8.074330        4.000000
# 25%            -0.271180  ...     -0.824409       2.571256      521.000000
# 50%             0.382181  ...      0.458341       4.976557      864.000000
# 75%             1.078775  ...      1.708533       7.772300     1483.000000
# max            10.507468  ...     10.141620      22.206864    17466.000000
#
#             OldPrice     OldIndex  Old1m%Change  Old12m%Change  \
# count    1862.000000  1862.000000   1862.000000    1862.000000
# mean   224933.469113   119.430335      0.377405       4.655862
# std     90574.035648    18.661383      1.436394       4.064243
# min    108864.361900    77.661143     -8.900000      -5.200000
# 25%    155976.781200   104.976106     -0.287394       1.782838
# 50%    204838.500000   118.528799      0.400000       4.346395
# 75%    263141.913175   131.300000      1.071217       7.100000
# max    548391.000000   163.100000      9.000000      20.600000
#
#        OldSalesVolume         Year   Month
# count     1862.000000  1862.000000  1862.0
# mean     19337.268528  2018.045113     1.0
# std      25885.795132     3.193577     0.0
# min        915.000000  2013.000000     1.0
# 25%       5275.250000  2015.000000     1.0
# 50%       7154.000000  2018.000000     1.0
# 75%      11707.000000  2021.000000     1.0
# max     163885.000000  2024.000000     1.0
#
# [8 rows x 53 columns]
